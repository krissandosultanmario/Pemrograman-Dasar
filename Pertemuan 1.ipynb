# %% [markdown]
# <a href="https://colab.research.google.com/github/krissandosultanmario/Pemrograman-Dasar/blob/main/Pertemuan%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Krissando Sultan Mario"
umur = 20
jurusan = "Elektro"
prodi = "TRPE"
semester = 3
alamat = "Perumahan Fanindo Blok Y No 7"
matakuliah = 'Pemerograman Dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (alamat)
print (matakuliah)
print (status_lulus)
# Out:
# Krissando Sultan Mario
# 20
# Elektro
# TRPE
# 3
# Perumahan Fanindo Blok Y No 7
# Pemerograman Dasar
# False
